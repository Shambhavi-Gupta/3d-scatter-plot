# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhavi-Gupta/3d-scatter-plot/blob/master/linkedin__3d_scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this plot you can see the total world population of different age of people
# ## 1. POP_014: This means the population of agegroup  between 0 to 14 years
# ## 2. POP_1564: This means the population of agegroup  between 15 to 64 years
# ## 3. POP_65: This means the population of agegroup above 65 years
# # So you can hover the mouse on any of the points and see all the deatils and It is a 3d graph so you can rotate it in any of the directions.

# %%
fig = px.scatter_3d(df, x='POP_014', y='POP_1564', z='POP_65',
              color='Years', size='Years', 
              symbol='Years')

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="34abbcf9-bfef-450e-9872-bb8e0cbe944d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34abbcf9-bfef-450e-9872-bb8e0cbe944d")) {
#                     Plotly.newPlot(
#                         '34abbcf9-bfef-450e-9872-bb8e0cbe944d',
# ...
